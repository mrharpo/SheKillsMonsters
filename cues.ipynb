# %%
from qlab.cues import Cues
from characters import characters

c = Cues(channels=characters, address="192.168.50.137")

# %%
c.q.send("/alwaysReply", 1)
# c.q.send('/cue/4/name', 'auto added')

# %%
# c.cues["1"]
# i = c.q.get_cue_property("1", "uniqueID")
# c.q.client.get_message()
# c.q.send('/cue/0/number', '0.0')

# c.cuelists

# %%
# c.q.send(f'/cue_id/{i}/number')
# c.q.send(f'/select_id/90E4A16E-3F5C-42B8-ACCA-EBE175667392')
# c.q.send("/new", "network")
# c.q.send("/new", ["network", '0604629E-DF21-4F44-93BE-338A9FBDD450'])
# c.q.send("/cue/17/colorName", "blue")

# %%
c.sync_cuelist("She Kills Monsters.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 c.sync_cuelist("She Kills Monsters")
#
# File ~/QLab-python/qlab/cues.py:101, in Cues.sync_cuelist(self, csv)
#      99 def sync_cuelist(self, csv: str):
#     100     """Synchronize the cuelist with the cues in the csv"""
# --> 101     csv_cues = open_csv(csv)
#     102     previous = None
#     103     for cue in csv_cues:
#
# File ~/QLab-python/qlab/cues.py:69, in open_csv(csv)
#      68 def open_csv(csv: str) -> list[Cue]:
# ---> 69     with open(csv, 'r') as f:
#      70         reader = DictReader(f)
#      71         return [Cue(**l) for l in list(reader)]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'She Kills Monsters'

# %%
from qlab.cues import QLabCue, flatten_cuelist

# c.cuelists

# c.cuelists[0].cues
# c.cues
# c.q.send('/cueLists')['data'][0]
# q = QLabCue(**c.q.send('/cueLists')['data'][0])
# f = flatten_cuelist(q)
# len(f)

# %%
# c.q.send('/new', ['network', '48aa2695-6b57-4625-8ad5-f73a1d21d6a7'])
# c.cues['10']
